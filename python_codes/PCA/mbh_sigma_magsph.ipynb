# %%
# %pylab inline
import sqlite3 as sql3
import os
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import matplotlib.colors as mcolors
from scipy import stats
from instruments.linear_regression import bces
from instruments import b_n

from mpl_toolkits.mplot3d import Axes3D
from mpl_toolkits.mplot3d import proj3d
from matplotlib.patches import FancyArrowPatch


class Arrow3D(FancyArrowPatch):
    def __init__(self, xs, ys, zs, *args, **kwargs):
        FancyArrowPatch.__init__(self, (0,0), (0,0), *args, **kwargs)
        self._verts3d = xs, ys, zs

    def draw(self, renderer):
        xs3d, ys3d, zs3d = self._verts3d
        xs, ys, zs = proj3d.proj_transform(xs3d, ys3d, zs3d, renderer.M)
        self.set_positions((xs[0],ys[0]),(xs[1],ys[1]))
        FancyArrowPatch.draw(self, renderer)

dbname = '/Users/gsavorgnan/galaxy_vivisection/python_codes/databases/galaxy_vivisection.db'
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.zmq.pylab.backend_inline].
# For more information, type 'help(pylab)'.

# %% [markdown]
# # Obtain the data from database

# %%
connection = sql3.connect(dbname)
cur = connection.cursor()

getdata_query = 'SELECT anc.gal_id, anc.simplemorphtype, anc.core, anc.bar, \
	anc.mass_BH, anc.perr_mass_BH, anc.merr_mass_BH, anc.sigma, \
	physres.mag_sph_eq_moffat_comb, physres.mag_tot_eq_moffat_comb, \
	physres.log_n_maj_moffat_comb, physres.log_n_eq_moffat_comb, \
	physres.mu_e_maj_moffat_comb, physres.mu_e_eq_moffat_comb, \
	physres.log_r_e_maj_moffat_comb, physres.log_r_e_eq_moffat_comb \
	FROM Ancillary AS anc \
	JOIN OneDFitResultsPhysicalUnits AS physres ON anc.gal_id = physres.gal_id \
	WHERE anc.fit1D_done = 1;'

cur.execute(getdata_query)
datalist = cur.fetchall()
data= np.asarray(datalist).transpose()
#print data
gal_id = data[0]
simplemorphtype = data[1]
core = data[2].astype(np.int)
bar = data[3].astype(np.int)

mbh = data[4].astype(np.float)
log_mbh = np.log10(mbh)
perr_mbh = data[5].astype(np.float)
merr_mbh = data[6].astype(np.float)
perr_log_mbh = np.log10(1 + perr_mbh/mbh)
merr_log_mbh = -np.log10(1 - merr_mbh/mbh)

sigma = data[7].astype(np.float)
# assign value to n3079
sigma[gal_id=='n3079'] = 105
log_sigma = np.log10(sigma)
err_log_sigma = sigma*[0.0] + np.log10(1.05)

mag_sph = data[8].astype(np.float)
mag_tot = data[9].astype(np.float)

log_n_maj = data[10].astype(np.float)
n_maj = 10**log_n_maj
log_n_eq = data[11].astype(np.float)
n_eq = 10**log_n_eq

mu_e_maj = data[12].astype(np.float)
mu_e_eq = data[13].astype(np.float)

# compute mu_0
b_maj = mu_e_maj * [0.0]
for i in range(len(b_maj)):
	b_maj[i] = b_n.computeb_n(n_maj[i])
b_eq = mu_e_eq * [0.0]
for i in range(len(b_eq)):
	b_eq[i] = b_n.computeb_n(n_eq[i])

mu_0_maj = mu_e_maj - 2.5*b_maj/np.log(10)
mu_0_eq = mu_e_eq - 2.5*b_eq/np.log(10)

log_r_e_maj = data[14].astype(np.float)
r_e_maj = 10**log_r_e_maj
log_r_e_eq = data[15].astype(np.float)
r_e_eq = 10**log_r_e_eq

# %% [markdown]
# # Build 3-dimensional dataset

# %% [markdown]
# We use black hole mass, sigma and mag_sph. The two classes are early and late type galaxies.

# %%
all_samples = np.array([log_mbh, log_sigma, mag_sph])

log_mbh_early = np.concatenate((log_mbh[simplemorphtype=='E'], log_mbh[simplemorphtype=='E/S0'], log_mbh[simplemorphtype=='S0']), axis=0)
log_sigma_early = np.concatenate((log_sigma[simplemorphtype=='E'], log_sigma[simplemorphtype=='E/S0'], log_sigma[simplemorphtype=='S0']), axis=0)
mag_sph_early = np.concatenate((mag_sph[simplemorphtype=='E'], mag_sph[simplemorphtype=='E/S0'], mag_sph[simplemorphtype=='S0']), axis=0)

early_sample = np.array([log_mbh_early, log_sigma_early, mag_sph_early])

log_mbh_late = log_mbh[simplemorphtype=='Sp']
log_sigma_late = log_sigma[simplemorphtype=='Sp']
mag_sph_late = mag_sph[simplemorphtype=='Sp']

late_sample = np.array([log_mbh_late, log_sigma_late, mag_sph_late])

# %% [markdown]
# # Visual inspection of data

# %%
from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from mpl_toolkits.mplot3d import proj3d

fig = plt.figure(figsize=(8,8))
ax = fig.add_subplot(111, projection='3d')
plt.rcParams['legend.fontsize'] = 10   
ax.plot(early_sample[0,:], early_sample[1,:], early_sample[2,:], 
        'o', markersize=8, color='red', alpha=0.5, label='class1')
ax.plot(late_sample[0,:], late_sample[1,:], late_sample[2,:], 
        '^', markersize=8, alpha=0.5, color='blue', label='class2')

plt.title('Samples for early and late')
ax.legend(loc='upper right')

plt.show()

# %% [markdown]
# # Computing the d-dimensional mean vector

# %%
mean_vector = np.array([[np.mean(log_mbh)], [np.mean(log_sigma)], [np.mean(mag_sph)]])
print 'Mean Vector:\n', mean_vector
# Out:
# Mean Vector:
# [[  8.16073498]
#  [  2.29696942]
#  [-23.85688991]]

# %% [markdown]
# # Using the PCA() class from the sklearn.decomposition library to confirm our results

# %%
all_samples.T.shape
#print all_samples.T
# Out:
# (66, 3)

# %%
average_matrix = np.array([np.average(all_samples.T, axis=0),]*66)
all_samples_T_norm = all_samples.T - average_matrix

# %%
from sklearn.decomposition import PCA as sklearnPCA

sklearn_pca = sklearnPCA(n_components=3)
sklearn_transf = sklearn_pca.fit_transform(all_samples_T_norm)

# %%
sklearn_transf.shape
# Out:
# (66, 3)

# %%
# this has to be zero
all_samples_T_norm - np.dot(sklearn_transf, sklearn_pca.components_)
# Out:
# array([[  1.77635684e-15,   8.88178420e-16,   3.10862447e-15],
#        [  2.22044605e-15,   2.22044605e-16,   4.44089210e-15],
#        [  1.66533454e-15,   3.88578059e-16,   6.66133815e-15],
#        [  1.77635684e-15,   8.32667268e-16,   5.43315393e-15],
#        [  1.72084569e-15,   6.80011603e-16,   5.44009282e-15],
#        [  1.77635684e-15,   9.71445147e-16,   4.88498131e-15],
#        [  1.67227343e-15,   8.18789481e-16,   5.10702591e-15],
#        [  1.55431223e-15,   5.27355937e-16,   6.21724894e-15],
#        [  1.83186799e-15,   5.06539255e-16,   5.55111512e-15],
#        [  2.44249065e-15,   4.44089210e-16,   3.99680289e-15],
#        [  1.88737914e-15,   6.80011603e-16,   4.99600361e-15],
#        [  1.88737914e-15,   4.44089210e-16,   6.21724894e-15],
#        [  1.55431223e-15,   7.49400542e-16,   6.21724894e-15],
#        [  1.77635684e-15,   6.66133815e-16,   5.55111512e-15],
#        [  2.22044605e-15,   4.99600361e-16,   4.44089210e-15],
#        [  1.99840144e-15,   4.44089210e-16,   4.66293670e-15],
#        [  1.66533454e-15,   1.02695630e-15,   5.77315973e-15],
#        [  2.22044605e-15,   3.74700271e-16,   4.96824804e-15],
#        [  2.22044605e-15,   6.38378239e-16,   4.44089210e-15],
#        [  1.72084569e-15,   8.74300632e-16,   4.88498131e-15],
#        [  1.99319727e-15,   3.95516953e-16,   5.77315973e-15],
#        [  1.55431223e-15,   7.77156117e-16,   5.99520433e-15],
#        [  1.44328993e-15,   8.60422844e-16,   5.32907052e-15],
#        [  1.66533454e-15,   1.94289029e-16,   6.66133815e-15],
#        [  2.22044605e-15,   3.05311332e-16,   4.10782519e-15],
#        [  1.99840144e-15,   8.04911693e-16,   4.44089210e-15],
#        [  1.88737914e-15,   8.46545056e-16,   4.44089210e-15],
#        [  1.88737914e-15,   1.20736754e-15,   3.55271368e-15],
#        [  1.84574578e-15,   8.32667268e-16,   5.10702591e-15],
#        [  2.22044605e-15,   1.11022302e-16,   4.44089210e-15],
#        [  1.33226763e-15,   6.10622664e-16,   6.21724894e-15],
#        [  1.66533454e-15,   8.32667268e-16,   5.60662627e-15],
#        [  1.99840144e-15,   7.21644966e-16,   4.44089210e-15],
#        [  1.74860126e-15,   9.85322934e-16,   5.32907052e-15],
#        [  1.83186799e-15,   6.10622664e-16,   5.05151476e-15],
#        [  2.10942375e-15,   5.55111512e-16,   4.66293670e-15],
#        [  2.22044605e-15,   4.71844785e-16,   4.77395901e-15],
#        [  1.88737914e-15,   5.82867088e-16,   5.32907052e-15],
#        [  1.77635684e-15,   6.66133815e-16,   4.44089210e-15],
#        [  1.77635684e-15,   3.81639165e-16,   5.99520433e-15],
#        [  1.92901251e-15,   2.77555756e-16,   5.55111512e-15],
#        [  1.85962357e-15,   5.20417043e-16,   5.44009282e-15],
#        [  8.88178420e-16,   6.10622664e-16,   7.10542736e-15],
#        [  1.66533454e-15,   1.22124533e-15,   5.10702591e-15],
#        [  1.72084569e-15,   1.13103971e-15,   5.32907052e-15],
#        [  1.94289029e-15,   5.82867088e-16,   4.94049246e-15],
#        [  1.88737914e-15,   4.16333634e-16,   5.55111512e-15],
#        [  1.77635684e-15,   7.21644966e-16,   5.44009282e-15],
#        [  1.77635684e-15,   6.66133815e-16,   3.99680289e-15],
#        [  1.94289029e-15,   5.75928194e-16,   4.82947016e-15],
#        [  1.87350135e-15,   5.75928194e-16,   5.19029264e-15],
#        [  1.77635684e-15,   8.04911693e-16,   4.88498131e-15],
#        [  1.88737914e-15,   7.49400542e-16,   4.88498131e-15],
#        [  1.84574578e-15,   4.44089210e-16,   5.32907052e-15],
#        [  1.77635684e-15,   7.21644966e-16,   6.21724894e-15],
#        [  2.22044605e-15,   4.99600361e-16,   3.99680289e-15],
#        [  1.88737914e-15,   5.41233725e-16,   5.99520433e-15],
#        [  1.99840144e-15,   3.88578059e-16,   5.07927034e-15],
#        [  1.87350135e-15,   4.99600361e-16,   5.44009282e-15],
#        [  1.83186799e-15,   9.15933995e-16,   5.10702591e-15],
#        [  1.66533454e-15,   5.13478149e-16,   6.43929354e-15],
#        [  1.99840144e-15,   2.22044605e-16,   6.66133815e-15],
#        [  2.05391260e-15,   2.22044605e-16,   5.77315973e-15],
#        [  1.55431223e-15,   4.99600361e-16,   6.66133815e-15],
#        [  1.55431223e-15,   2.77555756e-16,   7.10542736e-15],
#        [  1.77635684e-15,   3.88578059e-16,   5.32907052e-15]])

# %%
print sklearn_pca.explained_variance_ratio_
# Out:
# [ 0.93641913  0.06242995  0.00115092]

# %%
sklearn_pca.components_.shape
u = sklearn_pca.components_[0,:]
v = sklearn_pca.components_[1,:]
print 'first eigenv.', sklearn_pca.components_[0,:]
print 'second eigenv.', sklearn_pca.components_[1,:]

# cross product
n = np.cross(u,v)
print 'n = ', n
# Out:
# first eigenv. [ 0.40096703  0.06214626 -0.9139821 ]
# second eigenv. [ 0.90507942  0.12736304  0.40572145]
# n =  [ 0.14162161 -0.98990732 -0.00517892]

# %%
fig = plt.figure(figsize=(7,7))
ax = fig.add_subplot(111, projection='3d')

ax.plot(log_mbh, log_sigma, mag_sph,  
        'o', markersize=8, color='green', alpha=0.2)
#ax.plot([np.mean(log_mbh)], [np.mean(log_sigma)], [np.mean(log_r_e_maj)],  
#        'o', markersize=10, color='red', alpha=0.5)

for k in sklearn_pca.components_:
    print k
    a = Arrow3D([np.mean(log_mbh), k[0]+np.mean(log_mbh)], 
                [np.mean(log_sigma), k[1]+np.mean(log_sigma)], 
                [np.mean(mag_sph), k[2]+np.mean(mag_sph)], 
                mutation_scale=20, lw=3, arrowstyle="-|>", color="r")

    ax.add_artist(a)
ax.set_xlabel('log(Mbh)')
ax.set_ylabel('log(sigma)')
ax.set_zlabel('mag_sph')

plt.title('Eigenvectors')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-115758ddbd1a> in <module>()
#       9 for k in sklearn_pca.components_:
#      10     print k
# ---> 11     a = Arrow3D([np.mean(log_mbh), k[0]+np.mean(log_mbh)],
#      12                 [np.mean(log_sigma), k[1]+np.mean(log_sigma)],
#      13                 [np.mean(mag_sph), k[2]+np.mean(mag_sph)],
#
# NameError: name 'Arrow3D' is not defined
# [ 0.40096703  0.06214626 -0.9139821 ]

# %% [markdown]
# # Fundamental plane

# %%
plt.plot((-n[1]/n[0])*(log_sigma-np.average(log_sigma))+(-n[2]/n[0])*(log_r_e_maj-np.average(log_r_e_maj)),log_mbh-np.average(log_mbh), 
         'o', markersize=7, color='red', alpha=0.5, label='fundamental plane')

plt.plot((-n[1]/n[0])*(log_sigma-np.average(log_sigma)),log_mbh-np.average(log_mbh), 
         'o', markersize=7, color='blue', alpha=0.5, label='ignoring R_e contribution')

plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.title('Transformed samples using sklearn.decomposition.PCA()')
plt.show()

# %%
from instruments.linear_regression import bces

plt.plot((log_sigma-np.average(log_sigma)),log_mbh-np.average(log_mbh), 'o', markersize=7, color='blue', alpha=0.5, label='all')
plt.xlabel('log sigma')
plt.ylabel('log mbh')

A,B,Aerr,Berr,covAB=bces.bces(log_sigma-np.average(log_sigma),err_log_sigma, 
    log_mbh-np.average(log_mbh),0.5*(merr_log_mbh + perr_log_mbh), log_sigma*[0.0])
print 'bisector    A =', "{0:.4f}".format(A[2]), '+-', "{0:.4f}".format(Aerr[2]), '   B = ', "{0:.4f}".format(B[2]), '+-', "{0:.4f}".format(Berr[2])

yy = (A[2]*(log_sigma-np.average(log_sigma)) + B[2])
plt.plot(log_sigma-np.average(log_sigma),yy, color='k', ls='-', linewidth=1.5)

plt.show()
# Out:
# bisector    A = 5.8425 +- 0.3208    B =  -0.0000 +- 0.0527

# %%
plt.plot(log_r_e_maj, log_mbh - np.average(log_mbh) - yy, 'o', markersize=7, color='blue', alpha=0.5, label='all')
plt.xlabel('log R_e')
plt.ylabel('m-sigma residuals')

plt.show()
